# %%
#install and then import matplotlib
import matplotlib.pyplot as plt

# %%
#matplotlib to render plots in jupyter notebook
# %matplotlib inline

# %%
x=[-3,5,7]

# %%
y=[10,2,5]

# %%
fig = plt.figure(figsize=(15,3))
plt.plot(x, y)
plt.xlim (-3,10)
plt.ylim (0,8)
plt.xlable ('X Axis')
plt.ylable ('Y Axis')
plt.title('Line Plot')
plt.suptitle ('sales Comparison',size=20,y=1.03)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-d5399d5e792b> in <module>
#       3 plt.xlim (-3,10)
#       4 plt.ylim (0,8)
# ----> 5 plt.xlable ('X Axis')
#       6 plt.ylable ('Y Axis')
#       7 plt.title('Line Plot')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
fig.get_size_inches()
# Out:
# array([15.,  3.])

# %%
fig.set_size_inches(14,4)

# %%
fig

# %%
fig, ax = plt.subplots(nrows=1,ncols=1)

# %%
fig, ax=plt.subplots(2,4)

# %% [markdown]
# ## matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

mtcars= pd.read_csv("/Users/Srinivasgurra/Downloads/mtcars.csvR")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-9882ed5ab23b> in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 mtcars= pd.read_csv("/Users/Srinivasgurra/Downloads/mtcars.csvR")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-2d404ee6dbd6> in <module>
# ----> 1 mtcars= pd.read_csv("mtcars.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
mtcars.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-12f754267164> in <module>
# ----> 1 mtcars.columns
#
# NameError: name 'mtcars' is not defined

# %%
mtcars.shape

# %%
mtcars.head()

# %%
# table
pd.crosstab(mtcars.gears,mtcars,cyl)

# %%
# barplots between two different categories
pd.crosstab(mtcars.gears,mtcars.cyl).plot(kind='bar')

# %%
mtcars["gear"].value_counts()
mtcars.gear.value_counts(),plot(kind='pie')

# %%
mtcars["gear"].value_counts()
